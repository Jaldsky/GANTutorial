# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Voting classifier
#
# <img src=http://rasbt.github.io/mlxtend/user_guide/classifier/EnsembleVoteClassifier_files/majority_voting.png width=400/>
#
# </br>
#
# **Метод простого голосования**
# * $c_1, c_2, ..., c_m$ - обученные алгоритмы
# * Классификация: относим $x$ к классу, за который проголосовало *большинство* из $c_1(x), c_2(x), ..., c_m(x)$
# * Регрессия: ответом является среднее значение $c_1(x), c_2(x), ..., c_m(x)$

# %%
from sklearn.datasets import make_blobs
X1, y1 = make_blobs(n_samples=1000, centers=[[-2, 1], [0, -2]], cluster_std=1)
X2, y2 = make_blobs(n_samples=500, centers=[[3, 0], [1, 3]], cluster_std=1)
X = np.concatenate([X1, X2])
y = np.concatenate([y1, y2])

# %%
X
# Out:
# array([[-0.18644993,  0.46736241],
#        [-2.29457952,  1.52192409],
#        [ 0.43557184, -0.44986649],
#        ...,
#        [ 2.90788388,  0.65809377],
#        [ 0.8135728 ,  1.62290609],
#        [ 1.16205773,  3.9652873 ]])

# %%
def plot_blobs(x, y):

    fig, ax = plt.subplots(1, 1, figsize=(15, 10))
    reds = y == 0
    blues = y == 1
    
    ax.scatter(x[reds, 0], x[reds, 1], c="red", s=80, edgecolor="K")
    ax.scatter(x[blues, 0], x[blues, 1], c="blue", s=80, edgecolor="K")

    plt.show()

plot_blobs(X, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   import sys

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.shape, X_test.shape
# Out:
# ((1050, 2), (450, 2))

# %% [markdown]
# ## Логистическая регрессия

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
confusion_matrix(y_test, y_pred)
# Out:
# array([[137,  77],
#        [ 89, 147]])

# %%
def plot_confusion(model, X, y, class_names=('above average', 'below average')):
    ConfusionMatrixDisplay.from_estimator(model, X, y, cmap=plt.cm.Blues, display_labels=class_names, values_format='d')
plot_confusion(lr, X_train, y_train)
plot_confusion(lr, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3764a18c6f28> in <module>()
#       1 def plot_confusion(model, X, y, class_names=('above average', 'below average')):
#       2     ConfusionMatrixDisplay.from_estimator(model, X, y, cmap=plt.cm.Blues, display_labels=class_names, values_format='d')
# ----> 3 plot_confusion(lr, X_train, y_train)
#       4 plot_confusion(lr, X_test, y_test)
#
# NameError: name 'lr' is not defined

# %%
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
def plot_blob_classes(model, X, y):
    plt.figure(figsize=(15,8))

    eps = 0.1
    xx, yy = np.meshgrid(np.linspace(np.min(X[:,0]) - eps, np.max(X[:,0]) + eps, 500),
                         np.linspace(np.min(X[:,1]) - eps, np.max(X[:,1]) + eps, 500))

    colors = ("red", "blue")
    colored_y = np.zeros(y.size, dtype=str)

    for i, cl in enumerate([0,1]):
        colored_y[y == cl] = str(colors[i])

    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])

    Z = Z.reshape(xx.shape)

    cmap_light = ListedColormap(['#FFAAAA', 'grey'])
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
    plt.scatter(X[:, 0], X[:, 1], c=colored_y, edgecolors='K')
    plt.show()

plot_blob_classes(lr, X, y)

# %%
lr.score(X_test, y_test)
# Out:
# 0.6311111111111111

# %% [markdown]
# ## Дерево решений

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(max_depth=2)
dt.fit(X_train, y_train)
plot_confusion(dt, X_test, y_test)
plot_blob_classes(dt, X, y)
dt.score(X_test, y_test)
# Out:
# 0.8511111111111112

# %%
dt3 = DecisionTreeClassifier(max_depth=3)
dt3.fit(X_train, y_train)
plot_confusion(dt3, X_test, y_test)
plot_blob_classes(dt3, X, y)
dt3.score(X_test, y_test)
# Out:
# 0.8755555555555555

# %% [markdown]
# ## K-NN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
plot_confusion(knn, X_test, y_test)
plot_blob_classes(knn, X, y)

knn.score(X_test, y_test)
# Out:
# 0.8977777777777778

# %% [markdown]
# ## Наивный байесовский классификатор

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(X_train, y_train)
plot_confusion(gnb, X_test, y_test)
plot_blob_classes(gnb, X, y)
gnb.score(X_test, y_test)
# Out:
# 0.9066666666666666

# %% [markdown]
# ## Voting classifier

# %%
classifiers = [('lr', lr), ('dt2', dt), ('dt3', dt3), ('knn', knn), ('gnb', gnb)]
classifiers
# Out:
# [('lr', LogisticRegression()),
#  ('dt2', DecisionTreeClassifier(max_depth=2)),
#  ('dt3', DecisionTreeClassifier(max_depth=3)),
#  ('knn', KNeighborsClassifier(n_neighbors=1)),
#  ('gnb', GaussianNB())]

# %%
from sklearn.ensemble import VotingClassifier

vc = VotingClassifier(estimators=classifiers, voting='hard')
vc.fit(X_train, y_train)
plot_confusion(vc, X_test, y_test)
plot_blob_classes(vc, X, y)
vc.score(X_test, y_test)
# Out:
# 0.8911111111111111

# %%
params = {'lr__C' : [0.5, 1, 1.5], 
          'lr__class_weight': [None,'balanced'],
          'dt2__max_depth' : np.arange(1, 6),
          'dt3__max_depth' : np.arange(1, 6),
          'knn__n_neighbors' : np.arange(1, 20),
          'voting' : ['hard', 'soft']} 
np.prod([len(v) for k, v in params.items()])
# Out:
# 5700

# %%
# %%time
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
optimal = RandomizedSearchCV(estimator=vc, param_distributions=params, n_iter=500, cv=5, scoring='accuracy', n_jobs=-1).fit(X_train, y_train)
# Out:
# CPU times: user 8.19 s, sys: 150 ms, total: 8.34 s
# Wall time: 38.1 s

# %%
optimal.best_params_
# Out:
# {'dt2__max_depth': 5,
#  'dt3__max_depth': 4,
#  'knn__n_neighbors': 10,
#  'lr__C': 0.5,
#  'lr__class_weight': 'balanced',
#  'voting': 'hard'}

# %%
plot_confusion(optimal, X_test, y_test)
plot_blob_classes(optimal, X, y)
optimal.score(X_test, y_test)
# Out:
# 0.9088888888888889

# %% [markdown]
# # Случайный лес
#
#
# **Бутстрэп**
# <img src=https://cdn.analyticsvidhya.com/wp-content/uploads/2020/02/Bagging.png width=700/>
#
# </br>
#
# <image src=https://всеответы.рф/wp-content/uploads/2020/03/Random-forest.jpg width=800 />

# %% [markdown]
# ## Пятна

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(min_samples_split=10).fit(X_train, y_train)
plot_confusion(rf, X_test, y_test)
plot_blob_classes(rf, X, y)
rf.score(X_test, y_test)
# Out:
# 0.92

# %% [markdown]
# ## Титаник

# %%
# !wget -c https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# !ls
# Out:
# --2022-03-12 13:28:27--  https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# Resolving web.stanford.edu (web.stanford.edu)... 171.67.215.200, 2607:f6d0:0:925a::ab43:d7c8
# Connecting to web.stanford.edu (web.stanford.edu)|171.67.215.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44225 (43K) [text/csv]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  43.19K   277KB/s    in 0.2s
#
# 2022-03-12 13:28:28 (277 KB/s) - ‘titanic.csv’ saved [44225/44225]
#
# sample_data  titanic.csv

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0      male  22.0                        1                        0   7.2500
# 1    female  38.0                        1                        0  71.2833
# 2    female  26.0                        0                        0   7.9250
# 3    female  35.0                        1                        0  53.1000
# 4      male  35.0                        0                        0   8.0500
# ..      ...   ...                      ...                      ...      ...
# 882    male  27.0                        0                        0  13.0000
# 883  female  19.0                        0                        0  30.0000
# 884  female   7.0                        1                        2  23.4500
# 885    male  26.0                        0                        0  30.0000
# 886    male  32.0                        0                        0   7.7500
#
# [887 rows x 8 columns]

# %%
yt = df.Survived.values
Xt = df.drop(['Name', 'Survived'], axis=1)
Xt.sample(5)
# Out:
#      Pclass     Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 378       1  female  42.0                        0                        0
# 3         1  female  35.0                        1                        0
# 362       3    male  27.0                        1                        0
# 346       3    male   3.0                        1                        1
# 86        3    male  20.0                        0                        0
#
#         Fare
# 378  227.525
# 3     53.100
# 362   15.500
# 346   15.900
# 86     8.050

# %%
Xt['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
categories = {'female' : 1, 'male' : 0}
Xt['Sex'] = Xt['Sex'].map(categories)
Xt.sample(5)
# Out:
#      Pclass  Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 87        1    1  23.0                        3                        2
# 546       2    0   8.0                        1                        1
# 490       1    0  71.0                        0                        0
# 197       3    1  21.0                        0                        0
# 573       2    1  34.0                        0                        0
#
#          Fare
# 87   263.0000
# 546   36.7500
# 490   49.5042
# 197    7.7500
# 573   13.0000

# %%
from sklearn.model_selection import train_test_split
Xt_train, Xt_test, yt_train, yt_test = train_test_split(Xt, yt, test_size=0.25)

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier().fit(Xt_train, yt_train)
# Out:
# CPU times: user 216 ms, sys: 1.99 ms, total: 218 ms
# Wall time: 218 ms

# %%
plot_confusion(rf, Xt_test, yt_test, class_names=['died', 'survived'])

# %%
rf.score(Xt_test, yt_test)
# Out:
# 0.8153153153153153

# %%
sns.barplot(x=rf.feature_importances_, y=Xt_train.columns)

# %% [markdown]
# #Boosting
# <image src="https://upload.wikimedia.org/wikipedia/commons/b/b5/Ensemble_Boosting.svg" alt="boosting diagram" width=800/>

# %%
from sklearn.ensemble import AdaBoostClassifier

ab = AdaBoostClassifier().fit(X_train, y_train)
plot_blob_classes(ab, X, y)
ab.score(X_test, y_test)
# Out:
# 0.9

# %%
ab = AdaBoostClassifier().fit(Xt_train, yt_train)
sns.barplot(x=ab.feature_importances_, y=Xt_train.columns)
ab.score(Xt_test, yt_test)
# Out:
# 0.7972972972972973

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier().fit(X_train, y_train)
plot_blob_classes(gb, X, y)
gb.score(X_test, y_test)
# Out:
# 0.9133333333333333

# %%
gb = GradientBoostingClassifier().fit(Xt_train, yt_train)
sns.barplot(x=gb.feature_importances_, y=Xt_train.columns)
gb.score(Xt_test, yt_test)
# Out:
# 0.8063063063063063

# %% [markdown]
# # Перцептрон

# %%
from sklearn.datasets import make_blobs
X1, y1 = make_blobs(n_samples=1000, centers=[[-2, 1], [0, -2]], cluster_std=1)
X2, y2 = make_blobs(n_samples=500, centers=[[3, 0], [1, 3]], cluster_std=1)
X = np.concatenate([X1, X2])
y = np.concatenate([y1, y2])
plot_blobs(X, y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1200, 2), (1200,), (300, 2), (300,))

# %% [markdown]
# ## Keras
#
# [Keras](https://keras.io/) — библиотека, предоставляющая высокоуровневые cтроительные блоки для конструирования моделей глубокого обучения.
#
# |![Keras](https://www.digikey.com/maker-media/6c3d4f5f-98e0-4104-ad8c-fb0b47000109 "Title")|
# |:-------------------------------:|
# | Source: https://www.digikey.com/maker-media/6c3d4f5f-98e0-4104-ad8c-fb0b47000109 |

# %% [markdown]
# ### Определение модели
#
# Модель можно определить двумя способами:
# 1. с использованием класса Sequential (только для линейного стека слоев)
# 2. с помощью функционального API (для ориентированного ациклического графа слоев, позволяющего конструировать произвольные архитектуры). Функциональный API позволяет манипулировать данными в тензорах, которые обрабатывает модель, и применять слои к этим тензорам, как если бы они были функциями.

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()
model.add(Input(shape=(2,)))
model.add(Dense(4, activation='elu'))
model.add(Dense(4, activation='elu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 12
#
#  dense_1 (Dense)             (None, 4)                 20
#
#  dense_2 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 37
# Trainable params: 37
# Non-trainable params: 0
# _________________________________________________________________

# %%
# input_tensor = Input(shape=(2,))
# d1 = Dense(4, activation='elu')(input_tensor)
# d2 = Dense(4, activation='elu')(d1)
# output_tensor = Dense(1, activation='sigmoid')(d2)

# model = Model(inputs=input_tensor, outputs=output_tensor)
# model.summary()

# %%
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['binary_accuracy'])

# %% [markdown]
# ### Обучение модели
#
# Процесс обучения состоит в передаче массивов Numpy с входными данными (и соответствующими целевыми данными) в метод fit()
#
# Сеть перебирает обучающие данные пакетами по 32 образца. Для каждого пакета сеть вычисляет градиенты весов с учетом потерь в пакете и изменяет значения весов в соответствующем направлении.
#
# Можно разделить полный датасет из 1200 объектов на батчи размером 400 объектов. Таким образом, для завершения одной эпохи потребуется 3 итерации.

# %%
from tensorflow.keras.callbacks import EarlyStopping

results = model.fit(X_train, 
                    y_train,
                    batch_size=1200,
                    epochs=200000,
                    validation_split=0.2,
                    shuffle=True,
                    callbacks=[EarlyStopping(monitor='val_loss',
                                             patience=3,
                                             restore_best_weights=True)]
                    )
# Out:
# Epoch 1/200000
# 1/1 [==============================] - 1s 1s/step - loss: 0.6543 - binary_accuracy: 0.5927 - val_loss: 0.6409 - val_binary_accuracy: 0.5917
# Epoch 2/200000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6530 - binary_accuracy: 0.5938 - val_loss: 0.6396 - val_binary_accuracy: 0.5917
# Epoch 3/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6518 - binary_accuracy: 0.5938 - val_loss: 0.6384 - val_binary_accuracy: 0.5958
# Epoch 4/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6505 - binary_accuracy: 0.5958 - val_loss: 0.6372 - val_binary_accuracy: 0.5958
# Epoch 5/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6493 - binary_accuracy: 0.5990 - val_loss: 0.6360 - val_binary_accuracy: 0.5958
# Epoch 6/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6481 - binary_accuracy: 0.5990 - val_loss: 0.6348 - val_binary_accuracy: 0.5958
# Epoch 7/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6469 - binary_accuracy: 0.6000 - val_loss: 0.6336 - val_binary_accuracy: 0.5958
# Epoch 8/200000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6458 - binary_accuracy: 0.6010 - val_loss: 0.6325 - val_binary_accuracy: 0.5958
# Epoch 9/200000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.6446 - binary_accuracy: 0.6010 - val_loss: 0.6314 - val_binary_accuracy: 0.5958
# Epoch 10/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6435 - binary_accuracy: 0.6010 - val_loss: 0.6303 - val_binary_accuracy: 0.6000
# Epoch 11/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6424 - binary_accuracy: 0.6021 - val_loss: 0.6292 - val_binary_accuracy: 0.6042
# Epoch 12/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.6414 - binary_accuracy: 0.6021 - val_loss: 0.6282 - val_binary_accuracy: 0.6042
# Epoch 13/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6403 - binary_accuracy: 0.6042 - val_loss: 0.6272 - val_binary_accuracy: 0.6083
# Epoch 14/200000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6393 - binary_accuracy: 0.6042 - val_loss: 0.6262 - val_binary_accuracy: 0.6083
# Epoch 15/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6383 - binary_accuracy: 0.6083 - val_loss: 0.6252 - val_binary_accuracy: 0.6083
# Epoch 16/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6373 - binary_accuracy: 0.6083 - val_loss: 0.6242 - val_binary_accuracy: 0.6083
# Epoch 17/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6364 - binary_accuracy: 0.6083 - val_loss: 0.6233 - val_binary_accuracy: 0.6083
# Epoch 18/200000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6354 - binary_accuracy: 0.6104 - val_loss: 0.6223 - val_binary_accuracy: 0.6083
# Epoch 19/200000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6345 - binary_accuracy: 0.6104 - val_loss: 0.6214 - val_binary_accuracy: 0.6083
# Epoch 20/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6336 - binary_accuracy: 0.6135 - val_loss: 0.6205 - val_binary_accuracy: 0.6125
# Epoch 21/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6327 - binary_accuracy: 0.6146 - val_loss: 0.6196 - val_binary_accuracy: 0.6125
# Epoch 22/200000
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6318 - binary_accuracy: 0.6156 - val_loss: 0.6187 - val_binary_accuracy: 0.6125
# Epoch 23/200000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6309 - binary_accuracy: 0.6167 - val_loss: 0.6179 - val_binary_accuracy: 0.6125
# Epoch 24/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6300 - binary_accuracy: 0.6167 - val_loss: 0.6170 - val_binary_accuracy: 0.6167
# Epoch 25/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6292 - binary_accuracy: 0.6187 - val_loss: 0.6161 - val_binary_accuracy: 0.6292
# Epoch 26/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6283 - binary_accuracy: 0.6187 - val_loss: 0.6153 - val_binary_accuracy: 0.6292
# Epoch 27/200000
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6275 - binary_accuracy: 0.6219 - val_loss: 0.6145 - val_binary_accuracy: 0.6292
# Epoch 28/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6267 - binary_accuracy: 0.6229 - val_loss: 0.6136 - val_binary_accuracy: 0.6375
# Epoch 29/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6259 - binary_accuracy: 0.6208 - val_loss: 0.6128 - val_binary_accuracy: 0.6375
# Epoch 30/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6251 - binary_accuracy: 0.6208 - val_loss: 0.6120 - val_binary_accuracy: 0.6417
# Epoch 31/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.6243 - binary_accuracy: 0.6219 - val_loss: 0.6112 - val_binary_accuracy: 0.6458
# Epoch 32/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6235 - binary_accuracy: 0.6240 - val_loss: 0.6104 - val_binary_accuracy: 0.6458
# Epoch 33/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6227 - binary_accuracy: 0.6281 - val_loss: 0.6096 - val_binary_accuracy: 0.6458
# Epoch 34/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6220 - binary_accuracy: 0.6302 - val_loss: 0.6088 - val_binary_accuracy: 0.6458
# Epoch 35/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6212 - binary_accuracy: 0.6302 - val_loss: 0.6080 - val_binary_accuracy: 0.6417
# Epoch 36/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6204 - binary_accuracy: 0.6302 - val_loss: 0.6072 - val_binary_accuracy: 0.6417
# Epoch 37/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.6197 - binary_accuracy: 0.6313 - val_loss: 0.6064 - val_binary_accuracy: 0.6417
# Epoch 38/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6189 - binary_accuracy: 0.6323 - val_loss: 0.6056 - val_binary_accuracy: 0.6417
# Epoch 39/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6182 - binary_accuracy: 0.6344 - val_loss: 0.6048 - val_binary_accuracy: 0.6375
# Epoch 40/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6174 - binary_accuracy: 0.6333 - val_loss: 0.6040 - val_binary_accuracy: 0.6375
# Epoch 41/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6167 - binary_accuracy: 0.6344 - val_loss: 0.6032 - val_binary_accuracy: 0.6375
# Epoch 42/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6160 - binary_accuracy: 0.6354 - val_loss: 0.6025 - val_binary_accuracy: 0.6375
# Epoch 43/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6152 - binary_accuracy: 0.6354 - val_loss: 0.6017 - val_binary_accuracy: 0.6375
# Epoch 44/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6145 - binary_accuracy: 0.6365 - val_loss: 0.6009 - val_binary_accuracy: 0.6417
# Epoch 45/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6138 - binary_accuracy: 0.6417 - val_loss: 0.6001 - val_binary_accuracy: 0.6417
# Epoch 46/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6130 - binary_accuracy: 0.6448 - val_loss: 0.5993 - val_binary_accuracy: 0.6500
# Epoch 47/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6123 - binary_accuracy: 0.6458 - val_loss: 0.5985 - val_binary_accuracy: 0.6500
# Epoch 48/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6116 - binary_accuracy: 0.6458 - val_loss: 0.5977 - val_binary_accuracy: 0.6500
# Epoch 49/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6108 - binary_accuracy: 0.6458 - val_loss: 0.5969 - val_binary_accuracy: 0.6542
# Epoch 50/200000
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6101 - binary_accuracy: 0.6469 - val_loss: 0.5961 - val_binary_accuracy: 0.6542
# Epoch 51/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6094 - binary_accuracy: 0.6500 - val_loss: 0.5953 - val_binary_accuracy: 0.6542
# Epoch 52/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6086 - binary_accuracy: 0.6500 - val_loss: 0.5945 - val_binary_accuracy: 0.6542
# Epoch 53/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6079 - binary_accuracy: 0.6510 - val_loss: 0.5937 - val_binary_accuracy: 0.6542
# Epoch 54/200000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6072 - binary_accuracy: 0.6521 - val_loss: 0.5929 - val_binary_accuracy: 0.6583
# Epoch 55/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.6065 - binary_accuracy: 0.6531 - val_loss: 0.5921 - val_binary_accuracy: 0.6583
# Epoch 56/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6057 - binary_accuracy: 0.6552 - val_loss: 0.5913 - val_binary_accuracy: 0.6625
# Epoch 57/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6050 - binary_accuracy: 0.6573 - val_loss: 0.5905 - val_binary_accuracy: 0.6708
# Epoch 58/200000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6043 - binary_accuracy: 0.6573 - val_loss: 0.5897 - val_binary_accuracy: 0.6708
# Epoch 59/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6035 - binary_accuracy: 0.6573 - val_loss: 0.5889 - val_binary_accuracy: 0.6792
# Epoch 60/200000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6028 - binary_accuracy: 0.6583 - val_loss: 0.5880 - val_binary_accuracy: 0.6833
# Epoch 61/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6021 - binary_accuracy: 0.6583 - val_loss: 0.5872 - val_binary_accuracy: 0.6833
# Epoch 62/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6013 - binary_accuracy: 0.6594 - val_loss: 0.5864 - val_binary_accuracy: 0.6833
# Epoch 63/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6006 - binary_accuracy: 0.6615 - val_loss: 0.5856 - val_binary_accuracy: 0.6833
# Epoch 64/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5998 - binary_accuracy: 0.6625 - val_loss: 0.5848 - val_binary_accuracy: 0.6833
# Epoch 65/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5991 - binary_accuracy: 0.6635 - val_loss: 0.5840 - val_binary_accuracy: 0.6833
# Epoch 66/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5984 - binary_accuracy: 0.6635 - val_loss: 0.5832 - val_binary_accuracy: 0.6833
# Epoch 67/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5976 - binary_accuracy: 0.6656 - val_loss: 0.5823 - val_binary_accuracy: 0.6875
# Epoch 68/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5969 - binary_accuracy: 0.6656 - val_loss: 0.5815 - val_binary_accuracy: 0.6875
# Epoch 69/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5961 - binary_accuracy: 0.6677 - val_loss: 0.5807 - val_binary_accuracy: 0.6875
# Epoch 70/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5954 - binary_accuracy: 0.6687 - val_loss: 0.5798 - val_binary_accuracy: 0.6875
# Epoch 71/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5946 - binary_accuracy: 0.6687 - val_loss: 0.5790 - val_binary_accuracy: 0.6917
# Epoch 72/200000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.5938 - binary_accuracy: 0.6708 - val_loss: 0.5782 - val_binary_accuracy: 0.6917
# Epoch 73/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5931 - binary_accuracy: 0.6719 - val_loss: 0.5773 - val_binary_accuracy: 0.7000
# Epoch 74/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5923 - binary_accuracy: 0.6729 - val_loss: 0.5765 - val_binary_accuracy: 0.7042
# Epoch 75/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5915 - binary_accuracy: 0.6740 - val_loss: 0.5757 - val_binary_accuracy: 0.7042
# Epoch 76/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5908 - binary_accuracy: 0.6771 - val_loss: 0.5748 - val_binary_accuracy: 0.7083
# Epoch 77/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5900 - binary_accuracy: 0.6781 - val_loss: 0.5739 - val_binary_accuracy: 0.7083
# Epoch 78/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5892 - binary_accuracy: 0.6802 - val_loss: 0.5731 - val_binary_accuracy: 0.7083
# Epoch 79/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5884 - binary_accuracy: 0.6802 - val_loss: 0.5722 - val_binary_accuracy: 0.7125
# Epoch 80/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5876 - binary_accuracy: 0.6812 - val_loss: 0.5714 - val_binary_accuracy: 0.7125
# Epoch 81/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5869 - binary_accuracy: 0.6833 - val_loss: 0.5705 - val_binary_accuracy: 0.7125
# Epoch 82/200000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5861 - binary_accuracy: 0.6844 - val_loss: 0.5696 - val_binary_accuracy: 0.7125
# Epoch 83/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5853 - binary_accuracy: 0.6854 - val_loss: 0.5688 - val_binary_accuracy: 0.7125
# Epoch 84/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5845 - binary_accuracy: 0.6854 - val_loss: 0.5679 - val_binary_accuracy: 0.7125
# Epoch 85/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5836 - binary_accuracy: 0.6854 - val_loss: 0.5670 - val_binary_accuracy: 0.7167
# Epoch 86/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5828 - binary_accuracy: 0.6854 - val_loss: 0.5661 - val_binary_accuracy: 0.7167
# Epoch 87/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5820 - binary_accuracy: 0.6896 - val_loss: 0.5652 - val_binary_accuracy: 0.7167
# Epoch 88/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5812 - binary_accuracy: 0.6938 - val_loss: 0.5643 - val_binary_accuracy: 0.7167
# Epoch 89/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5804 - binary_accuracy: 0.6938 - val_loss: 0.5634 - val_binary_accuracy: 0.7125
# Epoch 90/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5795 - binary_accuracy: 0.6938 - val_loss: 0.5625 - val_binary_accuracy: 0.7125
# Epoch 91/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5787 - binary_accuracy: 0.6948 - val_loss: 0.5616 - val_binary_accuracy: 0.7125
# Epoch 92/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5779 - binary_accuracy: 0.6948 - val_loss: 0.5607 - val_binary_accuracy: 0.7167
# Epoch 93/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5770 - binary_accuracy: 0.6958 - val_loss: 0.5598 - val_binary_accuracy: 0.7208
# Epoch 94/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5762 - binary_accuracy: 0.6979 - val_loss: 0.5588 - val_binary_accuracy: 0.7208
# Epoch 95/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5753 - binary_accuracy: 0.6979 - val_loss: 0.5579 - val_binary_accuracy: 0.7208
# Epoch 96/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5745 - binary_accuracy: 0.7000 - val_loss: 0.5570 - val_binary_accuracy: 0.7208
# Epoch 97/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5736 - binary_accuracy: 0.7000 - val_loss: 0.5560 - val_binary_accuracy: 0.7208
# Epoch 98/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5728 - binary_accuracy: 0.7021 - val_loss: 0.5551 - val_binary_accuracy: 0.7208
# Epoch 99/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5719 - binary_accuracy: 0.7021 - val_loss: 0.5541 - val_binary_accuracy: 0.7208
# Epoch 100/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5710 - binary_accuracy: 0.7021 - val_loss: 0.5532 - val_binary_accuracy: 0.7208
# Epoch 101/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5702 - binary_accuracy: 0.7031 - val_loss: 0.5522 - val_binary_accuracy: 0.7208
# Epoch 102/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5693 - binary_accuracy: 0.7042 - val_loss: 0.5513 - val_binary_accuracy: 0.7250
# Epoch 103/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5684 - binary_accuracy: 0.7052 - val_loss: 0.5503 - val_binary_accuracy: 0.7250
# Epoch 104/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5675 - binary_accuracy: 0.7052 - val_loss: 0.5493 - val_binary_accuracy: 0.7250
# Epoch 105/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5666 - binary_accuracy: 0.7073 - val_loss: 0.5484 - val_binary_accuracy: 0.7250
# Epoch 106/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5657 - binary_accuracy: 0.7083 - val_loss: 0.5474 - val_binary_accuracy: 0.7250
# Epoch 107/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5648 - binary_accuracy: 0.7104 - val_loss: 0.5464 - val_binary_accuracy: 0.7250
# Epoch 108/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5639 - binary_accuracy: 0.7125 - val_loss: 0.5454 - val_binary_accuracy: 0.7292
# Epoch 109/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5630 - binary_accuracy: 0.7135 - val_loss: 0.5444 - val_binary_accuracy: 0.7292
# Epoch 110/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5621 - binary_accuracy: 0.7156 - val_loss: 0.5434 - val_binary_accuracy: 0.7292
# Epoch 111/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5611 - binary_accuracy: 0.7167 - val_loss: 0.5424 - val_binary_accuracy: 0.7292
# Epoch 112/200000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5602 - binary_accuracy: 0.7177 - val_loss: 0.5414 - val_binary_accuracy: 0.7333
# Epoch 113/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5593 - binary_accuracy: 0.7177 - val_loss: 0.5404 - val_binary_accuracy: 0.7333
# Epoch 114/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5584 - binary_accuracy: 0.7188 - val_loss: 0.5394 - val_binary_accuracy: 0.7333
# Epoch 115/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5574 - binary_accuracy: 0.7208 - val_loss: 0.5384 - val_binary_accuracy: 0.7375
# Epoch 116/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5565 - binary_accuracy: 0.7208 - val_loss: 0.5374 - val_binary_accuracy: 0.7375
# Epoch 117/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5555 - binary_accuracy: 0.7208 - val_loss: 0.5363 - val_binary_accuracy: 0.7375
# Epoch 118/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5546 - binary_accuracy: 0.7219 - val_loss: 0.5353 - val_binary_accuracy: 0.7375
# Epoch 119/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5536 - binary_accuracy: 0.7208 - val_loss: 0.5343 - val_binary_accuracy: 0.7417
# Epoch 120/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5527 - binary_accuracy: 0.7208 - val_loss: 0.5332 - val_binary_accuracy: 0.7417
# Epoch 121/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5517 - binary_accuracy: 0.7219 - val_loss: 0.5322 - val_binary_accuracy: 0.7417
# Epoch 122/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5507 - binary_accuracy: 0.7229 - val_loss: 0.5312 - val_binary_accuracy: 0.7417
# Epoch 123/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5498 - binary_accuracy: 0.7229 - val_loss: 0.5301 - val_binary_accuracy: 0.7417
# Epoch 124/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5488 - binary_accuracy: 0.7229 - val_loss: 0.5291 - val_binary_accuracy: 0.7417
# Epoch 125/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5478 - binary_accuracy: 0.7219 - val_loss: 0.5280 - val_binary_accuracy: 0.7417
# Epoch 126/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5468 - binary_accuracy: 0.7219 - val_loss: 0.5269 - val_binary_accuracy: 0.7417
# Epoch 127/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5458 - binary_accuracy: 0.7229 - val_loss: 0.5259 - val_binary_accuracy: 0.7417
# Epoch 128/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5448 - binary_accuracy: 0.7229 - val_loss: 0.5248 - val_binary_accuracy: 0.7458
# Epoch 129/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5438 - binary_accuracy: 0.7219 - val_loss: 0.5238 - val_binary_accuracy: 0.7458
# Epoch 130/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5428 - binary_accuracy: 0.7229 - val_loss: 0.5227 - val_binary_accuracy: 0.7458
# Epoch 131/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5418 - binary_accuracy: 0.7229 - val_loss: 0.5216 - val_binary_accuracy: 0.7500
# Epoch 132/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5408 - binary_accuracy: 0.7240 - val_loss: 0.5205 - val_binary_accuracy: 0.7542
# Epoch 133/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5398 - binary_accuracy: 0.7250 - val_loss: 0.5194 - val_binary_accuracy: 0.7542
# Epoch 134/200000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5388 - binary_accuracy: 0.7250 - val_loss: 0.5184 - val_binary_accuracy: 0.7542
# Epoch 135/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5378 - binary_accuracy: 0.7250 - val_loss: 0.5173 - val_binary_accuracy: 0.7500
# Epoch 136/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5368 - binary_accuracy: 0.7250 - val_loss: 0.5162 - val_binary_accuracy: 0.7542
# Epoch 137/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5357 - binary_accuracy: 0.7250 - val_loss: 0.5151 - val_binary_accuracy: 0.7542
# Epoch 138/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5347 - binary_accuracy: 0.7260 - val_loss: 0.5140 - val_binary_accuracy: 0.7542
# Epoch 139/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5337 - binary_accuracy: 0.7260 - val_loss: 0.5129 - val_binary_accuracy: 0.7542
# Epoch 140/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5326 - binary_accuracy: 0.7260 - val_loss: 0.5118 - val_binary_accuracy: 0.7542
# Epoch 141/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5316 - binary_accuracy: 0.7271 - val_loss: 0.5107 - val_binary_accuracy: 0.7542
# Epoch 142/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5306 - binary_accuracy: 0.7271 - val_loss: 0.5096 - val_binary_accuracy: 0.7542
# Epoch 143/200000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5295 - binary_accuracy: 0.7281 - val_loss: 0.5085 - val_binary_accuracy: 0.7542
# Epoch 144/200000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5285 - binary_accuracy: 0.7271 - val_loss: 0.5074 - val_binary_accuracy: 0.7542
# Epoch 145/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5274 - binary_accuracy: 0.7271 - val_loss: 0.5063 - val_binary_accuracy: 0.7542
# Epoch 146/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5263 - binary_accuracy: 0.7271 - val_loss: 0.5051 - val_binary_accuracy: 0.7542
# Epoch 147/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5253 - binary_accuracy: 0.7271 - val_loss: 0.5040 - val_binary_accuracy: 0.7542
# Epoch 148/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5242 - binary_accuracy: 0.7281 - val_loss: 0.5029 - val_binary_accuracy: 0.7542
# Epoch 149/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5232 - binary_accuracy: 0.7281 - val_loss: 0.5018 - val_binary_accuracy: 0.7542
# Epoch 150/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5221 - binary_accuracy: 0.7281 - val_loss: 0.5007 - val_binary_accuracy: 0.7542
# Epoch 151/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5210 - binary_accuracy: 0.7302 - val_loss: 0.4995 - val_binary_accuracy: 0.7500
# Epoch 152/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5199 - binary_accuracy: 0.7302 - val_loss: 0.4984 - val_binary_accuracy: 0.7500
# Epoch 153/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5189 - binary_accuracy: 0.7312 - val_loss: 0.4973 - val_binary_accuracy: 0.7500
# Epoch 154/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5178 - binary_accuracy: 0.7312 - val_loss: 0.4962 - val_binary_accuracy: 0.7500
# Epoch 155/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5167 - binary_accuracy: 0.7312 - val_loss: 0.4950 - val_binary_accuracy: 0.7500
# Epoch 156/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5156 - binary_accuracy: 0.7323 - val_loss: 0.4939 - val_binary_accuracy: 0.7500
# Epoch 157/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5145 - binary_accuracy: 0.7323 - val_loss: 0.4928 - val_binary_accuracy: 0.7500
# Epoch 158/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5134 - binary_accuracy: 0.7333 - val_loss: 0.4916 - val_binary_accuracy: 0.7500
# Epoch 159/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5123 - binary_accuracy: 0.7333 - val_loss: 0.4905 - val_binary_accuracy: 0.7583
# Epoch 160/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.5112 - binary_accuracy: 0.7344 - val_loss: 0.4893 - val_binary_accuracy: 0.7583
# Epoch 161/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5102 - binary_accuracy: 0.7333 - val_loss: 0.4882 - val_binary_accuracy: 0.7583
# Epoch 162/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5091 - binary_accuracy: 0.7344 - val_loss: 0.4871 - val_binary_accuracy: 0.7583
# Epoch 163/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5079 - binary_accuracy: 0.7354 - val_loss: 0.4859 - val_binary_accuracy: 0.7625
# Epoch 164/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5068 - binary_accuracy: 0.7354 - val_loss: 0.4848 - val_binary_accuracy: 0.7625
# Epoch 165/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5057 - binary_accuracy: 0.7375 - val_loss: 0.4836 - val_binary_accuracy: 0.7625
# Epoch 166/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.5046 - binary_accuracy: 0.7396 - val_loss: 0.4825 - val_binary_accuracy: 0.7667
# Epoch 167/200000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5035 - binary_accuracy: 0.7406 - val_loss: 0.4813 - val_binary_accuracy: 0.7667
# Epoch 168/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5024 - binary_accuracy: 0.7406 - val_loss: 0.4802 - val_binary_accuracy: 0.7667
# Epoch 169/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5013 - binary_accuracy: 0.7417 - val_loss: 0.4790 - val_binary_accuracy: 0.7667
# Epoch 170/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5002 - binary_accuracy: 0.7417 - val_loss: 0.4779 - val_binary_accuracy: 0.7667
# Epoch 171/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4990 - binary_accuracy: 0.7427 - val_loss: 0.4767 - val_binary_accuracy: 0.7667
# Epoch 172/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4979 - binary_accuracy: 0.7427 - val_loss: 0.4756 - val_binary_accuracy: 0.7667
# Epoch 173/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4968 - binary_accuracy: 0.7427 - val_loss: 0.4744 - val_binary_accuracy: 0.7667
# Epoch 174/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4956 - binary_accuracy: 0.7427 - val_loss: 0.4733 - val_binary_accuracy: 0.7667
# Epoch 175/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4945 - binary_accuracy: 0.7458 - val_loss: 0.4721 - val_binary_accuracy: 0.7667
# Epoch 176/200000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4934 - binary_accuracy: 0.7458 - val_loss: 0.4710 - val_binary_accuracy: 0.7667
# Epoch 177/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4922 - binary_accuracy: 0.7458 - val_loss: 0.4698 - val_binary_accuracy: 0.7667
# Epoch 178/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4911 - binary_accuracy: 0.7458 - val_loss: 0.4686 - val_binary_accuracy: 0.7667
# Epoch 179/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4900 - binary_accuracy: 0.7458 - val_loss: 0.4675 - val_binary_accuracy: 0.7667
# Epoch 180/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4888 - binary_accuracy: 0.7458 - val_loss: 0.4663 - val_binary_accuracy: 0.7667
# Epoch 181/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4877 - binary_accuracy: 0.7458 - val_loss: 0.4652 - val_binary_accuracy: 0.7708
# Epoch 182/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4865 - binary_accuracy: 0.7458 - val_loss: 0.4640 - val_binary_accuracy: 0.7708
# Epoch 183/200000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4854 - binary_accuracy: 0.7469 - val_loss: 0.4629 - val_binary_accuracy: 0.7708
# Epoch 184/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4842 - binary_accuracy: 0.7469 - val_loss: 0.4617 - val_binary_accuracy: 0.7750
# Epoch 185/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4831 - binary_accuracy: 0.7469 - val_loss: 0.4605 - val_binary_accuracy: 0.7750
# Epoch 186/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4819 - binary_accuracy: 0.7469 - val_loss: 0.4594 - val_binary_accuracy: 0.7750
# Epoch 187/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4808 - binary_accuracy: 0.7479 - val_loss: 0.4582 - val_binary_accuracy: 0.7750
# Epoch 188/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4796 - binary_accuracy: 0.7479 - val_loss: 0.4570 - val_binary_accuracy: 0.7750
# Epoch 189/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4785 - binary_accuracy: 0.7479 - val_loss: 0.4559 - val_binary_accuracy: 0.7750
# Epoch 190/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4773 - binary_accuracy: 0.7490 - val_loss: 0.4547 - val_binary_accuracy: 0.7750
# Epoch 191/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4762 - binary_accuracy: 0.7500 - val_loss: 0.4536 - val_binary_accuracy: 0.7750
# Epoch 192/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4750 - binary_accuracy: 0.7510 - val_loss: 0.4524 - val_binary_accuracy: 0.7750
# Epoch 193/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4738 - binary_accuracy: 0.7521 - val_loss: 0.4512 - val_binary_accuracy: 0.7750
# Epoch 194/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4727 - binary_accuracy: 0.7521 - val_loss: 0.4501 - val_binary_accuracy: 0.7792
# Epoch 195/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4715 - binary_accuracy: 0.7521 - val_loss: 0.4489 - val_binary_accuracy: 0.7792
# Epoch 196/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4704 - binary_accuracy: 0.7542 - val_loss: 0.4477 - val_binary_accuracy: 0.7792
# Epoch 197/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4692 - binary_accuracy: 0.7552 - val_loss: 0.4466 - val_binary_accuracy: 0.7792
# Epoch 198/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4680 - binary_accuracy: 0.7563 - val_loss: 0.4454 - val_binary_accuracy: 0.7792
# Epoch 199/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4669 - binary_accuracy: 0.7563 - val_loss: 0.4442 - val_binary_accuracy: 0.7792
# Epoch 200/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4657 - binary_accuracy: 0.7583 - val_loss: 0.4431 - val_binary_accuracy: 0.7792
# Epoch 201/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4646 - binary_accuracy: 0.7604 - val_loss: 0.4419 - val_binary_accuracy: 0.7792
# Epoch 202/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4634 - binary_accuracy: 0.7604 - val_loss: 0.4407 - val_binary_accuracy: 0.7792
# Epoch 203/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4623 - binary_accuracy: 0.7625 - val_loss: 0.4396 - val_binary_accuracy: 0.7792
# Epoch 204/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4611 - binary_accuracy: 0.7635 - val_loss: 0.4384 - val_binary_accuracy: 0.7792
# Epoch 205/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4599 - binary_accuracy: 0.7646 - val_loss: 0.4373 - val_binary_accuracy: 0.7792
# Epoch 206/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4588 - binary_accuracy: 0.7646 - val_loss: 0.4361 - val_binary_accuracy: 0.7792
# Epoch 207/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4576 - binary_accuracy: 0.7656 - val_loss: 0.4350 - val_binary_accuracy: 0.7833
# Epoch 208/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4565 - binary_accuracy: 0.7656 - val_loss: 0.4338 - val_binary_accuracy: 0.7833
# Epoch 209/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4553 - binary_accuracy: 0.7667 - val_loss: 0.4327 - val_binary_accuracy: 0.7833
# Epoch 210/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4542 - binary_accuracy: 0.7698 - val_loss: 0.4315 - val_binary_accuracy: 0.7875
# Epoch 211/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4530 - binary_accuracy: 0.7719 - val_loss: 0.4304 - val_binary_accuracy: 0.7875
# Epoch 212/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4519 - binary_accuracy: 0.7750 - val_loss: 0.4292 - val_binary_accuracy: 0.7917
# Epoch 213/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4508 - binary_accuracy: 0.7750 - val_loss: 0.4281 - val_binary_accuracy: 0.7917
# Epoch 214/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4496 - binary_accuracy: 0.7802 - val_loss: 0.4270 - val_binary_accuracy: 0.7958
# Epoch 215/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4485 - binary_accuracy: 0.7812 - val_loss: 0.4258 - val_binary_accuracy: 0.7958
# Epoch 216/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4474 - binary_accuracy: 0.7823 - val_loss: 0.4247 - val_binary_accuracy: 0.7958
# Epoch 217/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4462 - binary_accuracy: 0.7844 - val_loss: 0.4236 - val_binary_accuracy: 0.7958
# Epoch 218/200000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4451 - binary_accuracy: 0.7854 - val_loss: 0.4225 - val_binary_accuracy: 0.8000
# Epoch 219/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4440 - binary_accuracy: 0.7854 - val_loss: 0.4213 - val_binary_accuracy: 0.8000
# Epoch 220/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4429 - binary_accuracy: 0.7906 - val_loss: 0.4202 - val_binary_accuracy: 0.8000
# Epoch 221/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4418 - binary_accuracy: 0.7917 - val_loss: 0.4191 - val_binary_accuracy: 0.8000
# Epoch 222/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4407 - binary_accuracy: 0.7937 - val_loss: 0.4180 - val_binary_accuracy: 0.8000
# Epoch 223/200000
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4396 - binary_accuracy: 0.7979 - val_loss: 0.4169 - val_binary_accuracy: 0.8042
# Epoch 224/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4385 - binary_accuracy: 0.7990 - val_loss: 0.4158 - val_binary_accuracy: 0.8083
# Epoch 225/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4374 - binary_accuracy: 0.8000 - val_loss: 0.4147 - val_binary_accuracy: 0.8083
# Epoch 226/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4363 - binary_accuracy: 0.8000 - val_loss: 0.4137 - val_binary_accuracy: 0.8125
# Epoch 227/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4352 - binary_accuracy: 0.8010 - val_loss: 0.4126 - val_binary_accuracy: 0.8125
# Epoch 228/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4342 - binary_accuracy: 0.8010 - val_loss: 0.4115 - val_binary_accuracy: 0.8125
# Epoch 229/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4331 - binary_accuracy: 0.8010 - val_loss: 0.4104 - val_binary_accuracy: 0.8083
# Epoch 230/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4320 - binary_accuracy: 0.8031 - val_loss: 0.4094 - val_binary_accuracy: 0.8125
# Epoch 231/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4310 - binary_accuracy: 0.8062 - val_loss: 0.4083 - val_binary_accuracy: 0.8125
# Epoch 232/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4299 - binary_accuracy: 0.8073 - val_loss: 0.4073 - val_binary_accuracy: 0.8083
# Epoch 233/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4289 - binary_accuracy: 0.8104 - val_loss: 0.4062 - val_binary_accuracy: 0.8083
# Epoch 234/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4279 - binary_accuracy: 0.8125 - val_loss: 0.4052 - val_binary_accuracy: 0.8125
# Epoch 235/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4268 - binary_accuracy: 0.8125 - val_loss: 0.4042 - val_binary_accuracy: 0.8125
# Epoch 236/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4258 - binary_accuracy: 0.8115 - val_loss: 0.4031 - val_binary_accuracy: 0.8125
# Epoch 237/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4248 - binary_accuracy: 0.8125 - val_loss: 0.4021 - val_binary_accuracy: 0.8167
# Epoch 238/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4238 - binary_accuracy: 0.8135 - val_loss: 0.4011 - val_binary_accuracy: 0.8125
# Epoch 239/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.4228 - binary_accuracy: 0.8156 - val_loss: 0.4001 - val_binary_accuracy: 0.8125
# Epoch 240/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4218 - binary_accuracy: 0.8156 - val_loss: 0.3991 - val_binary_accuracy: 0.8167
# Epoch 241/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4208 - binary_accuracy: 0.8177 - val_loss: 0.3981 - val_binary_accuracy: 0.8208
# Epoch 242/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4198 - binary_accuracy: 0.8188 - val_loss: 0.3971 - val_binary_accuracy: 0.8167
# Epoch 243/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4189 - binary_accuracy: 0.8208 - val_loss: 0.3961 - val_binary_accuracy: 0.8208
# Epoch 244/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4179 - binary_accuracy: 0.8229 - val_loss: 0.3952 - val_binary_accuracy: 0.8292
# Epoch 245/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4169 - binary_accuracy: 0.8260 - val_loss: 0.3942 - val_binary_accuracy: 0.8292
# Epoch 246/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4160 - binary_accuracy: 0.8271 - val_loss: 0.3933 - val_binary_accuracy: 0.8292
# Epoch 247/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4151 - binary_accuracy: 0.8281 - val_loss: 0.3923 - val_binary_accuracy: 0.8292
# Epoch 248/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4141 - binary_accuracy: 0.8281 - val_loss: 0.3914 - val_binary_accuracy: 0.8333
# Epoch 249/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4132 - binary_accuracy: 0.8292 - val_loss: 0.3904 - val_binary_accuracy: 0.8375
# Epoch 250/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4123 - binary_accuracy: 0.8313 - val_loss: 0.3895 - val_binary_accuracy: 0.8375
# Epoch 251/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4114 - binary_accuracy: 0.8344 - val_loss: 0.3886 - val_binary_accuracy: 0.8375
# Epoch 252/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.4105 - binary_accuracy: 0.8344 - val_loss: 0.3876 - val_binary_accuracy: 0.8375
# Epoch 253/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4096 - binary_accuracy: 0.8333 - val_loss: 0.3867 - val_binary_accuracy: 0.8375
# Epoch 254/200000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.4087 - binary_accuracy: 0.8344 - val_loss: 0.3858 - val_binary_accuracy: 0.8417
# Epoch 255/200000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4078 - binary_accuracy: 0.8333 - val_loss: 0.3849 - val_binary_accuracy: 0.8375
# Epoch 256/200000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.4069 - binary_accuracy: 0.8333 - val_loss: 0.3840 - val_binary_accuracy: 0.8417
# Epoch 257/200000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4060 - binary_accuracy: 0.8333 - val_loss: 0.3832 - val_binary_accuracy: 0.8417
# Epoch 258/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4052 - binary_accuracy: 0.8344 - val_loss: 0.3823 - val_binary_accuracy: 0.8458
# Epoch 259/200000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4043 - binary_accuracy: 0.8354 - val_loss: 0.3814 - val_binary_accuracy: 0.8500
# Epoch 260/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4035 - binary_accuracy: 0.8375 - val_loss: 0.3805 - val_binary_accuracy: 0.8500
# Epoch 261/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4026 - binary_accuracy: 0.8354 - val_loss: 0.3797 - val_binary_accuracy: 0.8500
# Epoch 262/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4018 - binary_accuracy: 0.8385 - val_loss: 0.3788 - val_binary_accuracy: 0.8500
# Epoch 263/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4009 - binary_accuracy: 0.8396 - val_loss: 0.3780 - val_binary_accuracy: 0.8542
# Epoch 264/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4001 - binary_accuracy: 0.8396 - val_loss: 0.3771 - val_binary_accuracy: 0.8542
# Epoch 265/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3993 - binary_accuracy: 0.8406 - val_loss: 0.3763 - val_binary_accuracy: 0.8583
# Epoch 266/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3985 - binary_accuracy: 0.8406 - val_loss: 0.3755 - val_binary_accuracy: 0.8583
# Epoch 267/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3977 - binary_accuracy: 0.8396 - val_loss: 0.3746 - val_binary_accuracy: 0.8583
# Epoch 268/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3969 - binary_accuracy: 0.8396 - val_loss: 0.3738 - val_binary_accuracy: 0.8583
# Epoch 269/200000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3961 - binary_accuracy: 0.8417 - val_loss: 0.3730 - val_binary_accuracy: 0.8500
# Epoch 270/200000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3953 - binary_accuracy: 0.8406 - val_loss: 0.3722 - val_binary_accuracy: 0.8500
# Epoch 271/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3945 - binary_accuracy: 0.8406 - val_loss: 0.3714 - val_binary_accuracy: 0.8500
# Epoch 272/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3937 - binary_accuracy: 0.8406 - val_loss: 0.3706 - val_binary_accuracy: 0.8500
# Epoch 273/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3930 - binary_accuracy: 0.8396 - val_loss: 0.3698 - val_binary_accuracy: 0.8542
# Epoch 274/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3922 - binary_accuracy: 0.8396 - val_loss: 0.3690 - val_binary_accuracy: 0.8542
# Epoch 275/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3914 - binary_accuracy: 0.8396 - val_loss: 0.3682 - val_binary_accuracy: 0.8542
# Epoch 276/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3907 - binary_accuracy: 0.8396 - val_loss: 0.3675 - val_binary_accuracy: 0.8542
# Epoch 277/200000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3899 - binary_accuracy: 0.8396 - val_loss: 0.3667 - val_binary_accuracy: 0.8542
# Epoch 278/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3892 - binary_accuracy: 0.8406 - val_loss: 0.3659 - val_binary_accuracy: 0.8542
# Epoch 279/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3884 - binary_accuracy: 0.8406 - val_loss: 0.3652 - val_binary_accuracy: 0.8542
# Epoch 280/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.3877 - binary_accuracy: 0.8406 - val_loss: 0.3644 - val_binary_accuracy: 0.8542
# Epoch 281/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3870 - binary_accuracy: 0.8438 - val_loss: 0.3636 - val_binary_accuracy: 0.8542
# Epoch 282/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3863 - binary_accuracy: 0.8438 - val_loss: 0.3629 - val_binary_accuracy: 0.8542
# Epoch 283/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3855 - binary_accuracy: 0.8438 - val_loss: 0.3622 - val_binary_accuracy: 0.8542
# Epoch 284/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3848 - binary_accuracy: 0.8448 - val_loss: 0.3614 - val_binary_accuracy: 0.8542
# Epoch 285/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3841 - binary_accuracy: 0.8479 - val_loss: 0.3607 - val_binary_accuracy: 0.8542
# Epoch 286/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3834 - binary_accuracy: 0.8490 - val_loss: 0.3599 - val_binary_accuracy: 0.8583
# Epoch 287/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3827 - binary_accuracy: 0.8500 - val_loss: 0.3592 - val_binary_accuracy: 0.8583
# Epoch 288/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3820 - binary_accuracy: 0.8510 - val_loss: 0.3585 - val_binary_accuracy: 0.8583
# Epoch 289/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3813 - binary_accuracy: 0.8510 - val_loss: 0.3578 - val_binary_accuracy: 0.8625
# Epoch 290/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3806 - binary_accuracy: 0.8510 - val_loss: 0.3570 - val_binary_accuracy: 0.8625
# Epoch 291/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3799 - binary_accuracy: 0.8510 - val_loss: 0.3563 - val_binary_accuracy: 0.8625
# Epoch 292/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3792 - binary_accuracy: 0.8510 - val_loss: 0.3556 - val_binary_accuracy: 0.8625
# Epoch 293/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3786 - binary_accuracy: 0.8510 - val_loss: 0.3549 - val_binary_accuracy: 0.8625
# Epoch 294/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3779 - binary_accuracy: 0.8479 - val_loss: 0.3542 - val_binary_accuracy: 0.8625
# Epoch 295/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3772 - binary_accuracy: 0.8479 - val_loss: 0.3535 - val_binary_accuracy: 0.8625
# Epoch 296/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3766 - binary_accuracy: 0.8479 - val_loss: 0.3528 - val_binary_accuracy: 0.8625
# Epoch 297/200000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3759 - binary_accuracy: 0.8479 - val_loss: 0.3521 - val_binary_accuracy: 0.8625
# Epoch 298/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3752 - binary_accuracy: 0.8479 - val_loss: 0.3514 - val_binary_accuracy: 0.8625
# Epoch 299/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3746 - binary_accuracy: 0.8479 - val_loss: 0.3508 - val_binary_accuracy: 0.8625
# Epoch 300/200000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3739 - binary_accuracy: 0.8490 - val_loss: 0.3501 - val_binary_accuracy: 0.8625
# Epoch 301/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3733 - binary_accuracy: 0.8490 - val_loss: 0.3494 - val_binary_accuracy: 0.8625
# Epoch 302/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3726 - binary_accuracy: 0.8510 - val_loss: 0.3487 - val_binary_accuracy: 0.8625
# Epoch 303/200000
# ...
# Epoch 1536/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1726 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1537/200000
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1726 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1538/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1726 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1539/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1726 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1540/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1725 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1541/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1725 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1542/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1725 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1543/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1725 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1544/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1725 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1545/200000
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1725 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1546/200000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1725 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1547/200000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1725 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1548/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1725 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1549/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1725 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1550/200000
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1725 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1551/200000
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1725 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1552/200000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1724 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1553/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1724 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1554/200000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.1724 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1555/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1724 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1556/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1724 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1557/200000
# 1/1 [==============================] - 0s 54ms/step - loss: 0.1724 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1558/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1724 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1559/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1724 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1560/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1724 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1561/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1724 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1562/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1724 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1563/200000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1723 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1564/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1723 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1565/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1723 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1566/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1723 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1567/200000
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1723 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1568/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1723 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1569/200000
# 1/1 [==============================] - 0s 53ms/step - loss: 0.1723 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1570/200000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1723 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1571/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1723 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1572/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1723 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1573/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1723 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1574/200000
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1723 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1575/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1722 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1576/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1722 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1577/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1722 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1578/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1722 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1579/200000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1722 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1580/200000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1722 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1581/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1722 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1582/200000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1722 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1583/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1722 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1584/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1722 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1585/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1722 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1586/200000
# 1/1 [==============================] - 0s 48ms/step - loss: 0.1722 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1587/200000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1721 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1588/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1721 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1589/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1721 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1590/200000
# 1/1 [==============================] - 0s 51ms/step - loss: 0.1721 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1591/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1721 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1592/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1721 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1593/200000
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1721 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1594/200000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1721 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1595/200000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1721 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1596/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1721 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1597/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1721 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1598/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1721 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1599/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1721 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1600/200000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1720 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1601/200000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1720 - binary_accuracy: 0.9344 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1602/200000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1720 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1603/200000
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1720 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1604/200000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.1720 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1605/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1720 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1606/200000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1720 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1607/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1720 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1608/200000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1720 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1609/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1720 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1610/200000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1720 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1611/200000
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1720 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1612/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1613/200000
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1614/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1615/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1616/200000
# 1/1 [==============================] - 0s 47ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1617/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1618/200000
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1619/200000
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1620/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1621/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1622/200000
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1623/200000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1624/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1625/200000
# 1/1 [==============================] - 0s 42ms/step - loss: 0.1719 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1626/200000
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1718 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1627/200000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1718 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1628/200000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1718 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1629/200000
# 1/1 [==============================] - 0s 50ms/step - loss: 0.1718 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1630/200000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1718 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1631/200000
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1718 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1632/200000
# 1/1 [==============================] - 0s 52ms/step - loss: 0.1718 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1633/200000
# 1/1 [==============================] - 0s 49ms/step - loss: 0.1718 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1634/200000
# 1/1 [==============================] - 0s 46ms/step - loss: 0.1718 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292
# Epoch 1635/200000
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1718 - binary_accuracy: 0.9333 - val_loss: 0.1606 - val_binary_accuracy: 0.9292

# %% [markdown]
# ### Объект history
#
# Вызов `model.fit()` возвращает объект History. Этот объект имеет поле *history* - словарь со значениями функции потерь и метрики

# %%
results

# %%
results.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
hist = pd.DataFrame(results.history)
hist
# Out:
#           loss  binary_accuracy  val_loss  val_binary_accuracy
# 0     0.654340         0.592708  0.640930             0.591667
# 1     0.653044         0.593750  0.639649             0.591667
# 2     0.651771         0.593750  0.638394             0.595833
# 3     0.650522         0.595833  0.637164             0.595833
# 4     0.649298         0.598958  0.635959             0.595833
# ...        ...              ...       ...                  ...
# 1630  0.171806         0.933333  0.160574             0.929167
# 1631  0.171799         0.933333  0.160573             0.929167
# 1632  0.171791         0.933333  0.160574             0.929167
# 1633  0.171784         0.933333  0.160574             0.929167
# 1634  0.171777         0.933333  0.160574             0.929167
#
# [1635 rows x 4 columns]

# %%
hist[['loss']].plot()
hist[['binary_accuracy']].plot()

# %%
loss, acc = model.evaluate(X_test, y_test, batch_size=300)
print('Test loss:', loss)
print('Test accuracy:', acc)
# Out:
# 1/1 [==============================] - 0s 173ms/step - loss: 0.1495 - binary_accuracy: 0.9400
# Test loss: 0.14948630332946777
# Test accuracy: 0.9399999976158142

# %%
plot_blob_classes(model, X, y)

# %% [markdown]
# # Задание
#
# 1. Применить один из бустовых классификаторов к своей модели, визуализировать оценку важности признаков
